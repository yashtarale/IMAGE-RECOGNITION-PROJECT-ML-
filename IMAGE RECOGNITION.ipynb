# %%
import tensorflow as tf  ## run A  prompt as admins. and pip install tensorflow

# %%
import numpy as np ##pip install numpy

# %%
filename = 'image_data//car.jpg'

# %% [markdown]
# # First method to load an image

# %%
from IPython.display import Image ##first method
Image (filename='image_data//car.jpg',width=224, height=224)

# %% [markdown]
# # second method to load an image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size =(224,224))

# %%
import matplotlib.pyplot as plt ##conda install -c conda-forge matplotlib

# %%
plt.imshow(img)

# %% [markdown]
# # Thirt method to load an image

# %%
import cv2 ##pip install opencv-python

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg=cv2.resize(imgg,(224,224))  #changed size

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg,cv2.COLOR_BGR2RGB))  #converted from grb to rgb

# %% [markdown]
# # Fourth image to load an image

# %%
from PIL import Image #pip install pillow

# %%
im = Image.open('image_data//car.jpg') #PIL

# %%
im=im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# # Lets load deep learning model

# %%
# The tensorflow.keras.applications module has a function named MobileNet() 
#for loading the MobileNet model as given below. It returns the model as it is without any changes.

#do it only for first time

import tensorflow as tf

base_model = tf.keras.applications.MobileNet()

# %% [raw]
# TensorFlow has a module tensorflow.keras.applications which holds a number of pre-trained deep learning models. When loading any of such models, not only their architectures are existing but also their trained weights. So, you are ready to either use them for making predictions or transfer learning.

# %%
mobile = tf.keras.applications.mobilenet.MobileNet() #deep learnig model weights - pre-trained   --version1--

# %% [markdown]
# #### creating a model
# #### Training a model
# #### Test or validate
# #### predict

# %%
## predicting again lines after ---------------------------- :     --version2--
mobile =tf.keras.applications.mobilenet_v2.MobileNetV2()

# %% [markdown]
# # pre-processing of image

# %%
#changine file name for predictions examples
filename = 'image_data\\1.jpg'

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size =(224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis=0) ##need fourth dimension
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)

# %% [raw]
# ## print(predictions)

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results) ##mobilenet version 2 predictions--of2018
# Out:
# [[('n01514859', 'hen', 0.81930727), ('n01514668', 'cock', 0.094892226), ('n02002556', 'white_stork', 0.009978155), ('n01855672', 'goose', 0.00731881), ('n01819313', 'sulphur-crested_cockatoo', 0.004258117)]]

# %%
print(results)  ##mobilenet version 1 predictions--of2017
# Out:
# [[('n01514859', 'hen', 0.8978834), ('n01514668', 'cock', 0.05272289), ('n01855672', 'goose', 0.026377453), ('n01796340', 'ptarmigan', 0.008469389), ('n02058221', 'albatross', 0.0035876087)]]

# %%
plt.imshow(img)

# %% [markdown]
# # ----------------------------------------

# %%
predictions = mobile.predict(final_image)

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n01514859', 'hen', 0.81930727), ('n01514668', 'cock', 0.094892226), ('n02002556', 'white_stork', 0.009978155), ('n01855672', 'goose', 0.00731881), ('n01819313', 'sulphur-crested_cockatoo', 0.004258117)]]
